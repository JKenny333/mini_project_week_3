# %%
import pandas as pd

# %%
life_expectancy_record_df = pd.read_csv('https://raw.githubusercontent.com/JKenny333/mini_project_week_3/main/csv_files/cleaned_csv_files/life_expectancy_data_clean.csv')

# %%
countries_df = pd.read_csv('https://raw.githubusercontent.com/JKenny333/mini_project_week_3/main/csv_files/table_csv_files/country_table.csv')

# %%
life_expectancy_record_df
# Out:
#           country  year development_status  life_expectancy  adult_mortality  \
# 0     Afghanistan  2015         Developing             65.0            263.0
# 1     Afghanistan  2014         Developing             59.9            271.0
# 2     Afghanistan  2013         Developing             59.9            268.0
# 3     Afghanistan  2012         Developing             59.5            272.0
# 4     Afghanistan  2011         Developing             59.2            275.0
# ...           ...   ...                ...              ...              ...
# 2933     Zimbabwe  2004         Developing             44.3            723.0
# 2934     Zimbabwe  2003         Developing             44.5            715.0
# 2935     Zimbabwe  2002         Developing             44.8             73.0
# 2936     Zimbabwe  2001         Developing             45.3            686.0
# 2937     Zimbabwe  2000         Developing             46.0            665.0
#
# ...

# %%
countries_df
# Out:
#      Unnamed: 0  country_id         country_name
# 0             0           1          Afghanistan
# 1             1           2              Albania
# 2             2           3              Algeria
# 3             3           4               Angola
# 4             4           5  Antigua and Barbuda
# ..          ...         ...                  ...
# 187         187         188            Venezuela
# 188         188         189              Vietnam
# 189         189         190                Yemen
# 190         190         191               Zambia
# 191         191         192             Zimbabwe
#
# [192 rows x 3 columns]

# %%
merged_df = life_expectancy_record_df.merge(countries_df[['country_id', 'country_name']], how='left', left_on='country', right_on='country_name')

# %%
merged_df = merged_df.drop('country_name', axis=1)
merged_df
# Out:
#           country  year development_status  life_expectancy  adult_mortality  \
# 0     Afghanistan  2015         Developing             65.0            263.0
# 1     Afghanistan  2014         Developing             59.9            271.0
# 2     Afghanistan  2013         Developing             59.9            268.0
# 3     Afghanistan  2012         Developing             59.5            272.0
# 4     Afghanistan  2011         Developing             59.2            275.0
# ...           ...   ...                ...              ...              ...
# 2933     Zimbabwe  2004         Developing             44.3            723.0
# 2934     Zimbabwe  2003         Developing             44.5            715.0
# 2935     Zimbabwe  2002         Developing             44.8             73.0
# 2936     Zimbabwe  2001         Developing             45.3            686.0
# 2937     Zimbabwe  2000         Developing             46.0            665.0
#
# ...

# %%
merged_df = merged_df.drop('country', axis=1)
merged_df
# Out:
#       year development_status  life_expectancy  adult_mortality  \
# 0     2015         Developing             65.0            263.0
# 1     2014         Developing             59.9            271.0
# 2     2013         Developing             59.9            268.0
# 3     2012         Developing             59.5            272.0
# 4     2011         Developing             59.2            275.0
# ...    ...                ...              ...              ...
# 2933  2004         Developing             44.3            723.0
# 2934  2003         Developing             44.5            715.0
# 2935  2002         Developing             44.8             73.0
# 2936  2001         Developing             45.3            686.0
# 2937  2000         Developing             46.0            665.0
#
#       infant_deaths  alcohol  percentage_expenditure   bmi  under-five_deaths  \
# 0                62     0.01               71.279624  19.1                 83
# ...

# %%
merged_df.to_csv('life_expectancy_record_table.csv')
