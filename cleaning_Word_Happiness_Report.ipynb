# %%
import pandas as pd


Life_Expectancy_Data = pd.read_csv('/Users/hana/Documents/week3_project/Life Expectancy Data.csv')
World_Happiness1_Report = pd.read_csv('/Users/hana/Documents/week3_project/archive (4) 2/2015.csv')
World_Happiness2_Report = pd.read_csv('/Users/hana/Documents/week3_project/archive (4) 2/2016.csv')
World_Happiness3_Report = pd.read_csv('/Users/hana/Documents/week3_project/archive (4) 2/2017.csv')
World_Happiness4_Report = pd.read_csv('/Users/hana/Documents/week3_project/archive (4) 2/2018.csv')
World_Happiness5_Report = pd.read_csv('/Users/hana/Documents/week3_project/archive (4) 2/2019.csv')

# %%
def data_frame_overview(data_frame):
    print(f'Column names: \n {data_frame.columns}\n')
    print(f'Dimensions: {data_frame.shape}\n')
    print(data_frame.info())
    return data_frame.head(10)

# %%
data_frame_overview(World_Happiness1_Report)
# Out:
# Column names:
#  Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
#
# Dimensions: (158, 12)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
# ...

# %%
World_Happiness1_Report.columns = [name.strip().replace(" ", "_").lower() for name in World_Happiness1_Report.columns]

# %%
World_Happiness1_Report.columns
# Out:
# Index(['country', 'region', 'happiness_rank', 'happiness_score',
#        'standard_error', 'economy_(gdp_per_capita)', 'family',
#        'health_(life_expectancy)', 'freedom', 'trust_(government_corruption)',
#        'generosity', 'dystopia_residual'],
#       dtype='object')

# %%
def null_check(data_frame):
    print(f'Total null values per row: \n{data_frame.isnull().sum(axis=1)}\n')
    print(f'Total null values per column: \n{data_frame.isnull().sum()}\n')

# %%
null_check(World_Happiness1_Report)
# Out:
# Total null values per row:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 153    0
# 154    0
# 155    0
# 156    0
# 157    0
# Length: 158, dtype: int64
#
# Total null values per column:
# country                          0
# region                           0
# happiness_rank                   0
# happiness_score                  0
# standard_error                   0
# economy_(gdp_per_capita)         0
# family                           0
# health_(life_expectancy)         0
# freedom                          0
# trust_(government_corruption)    0
# generosity                       0
# dystopia_residual                0
# dtype: int64

# %%
def dup_check(data_frame):
    print(f'Duplicates found: {data_frame.duplicated().any()}\n')
    print(f'Number of duplicates: {data_frame.duplicated().sum()}\n')

# %%
dup_check(World_Happiness1_Report)
# Out:
# Duplicates found: False
#
# Number of duplicates: 0

# %%
data_frame_overview(World_Happiness2_Report)
# Out:
# Column names:
#  Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')
#
# Dimensions: (157, 13)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
# ...

# %%
World_Happiness2_Report.columns
# Out:
# Index(['country', 'region', 'happiness_rank', 'happiness_score',
#        'lower_confidence_interval', 'upper_confidence_interval',
#        'economy_(gdp_per_capita)', 'family', 'health_(life_expectancy)',
#        'freedom', 'trust_(government_corruption)', 'generosity',
#        'dystopia_residual'],
#       dtype='object')

# %%
null_check(World_Happiness2_Report)
# Out:
# Total null values per row:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 152    0
# 153    0
# 154    0
# 155    0
# 156    0
# Length: 157, dtype: int64
#
# Total null values per column:
# country                          0
# region                           0
# happiness_rank                   0
# happiness_score                  0
# lower_confidence_interval        0
# upper_confidence_interval        0
# economy_(gdp_per_capita)         0
# family                           0
# health_(life_expectancy)         0
# freedom                          0
# trust_(government_corruption)    0
# generosity                       0
# dystopia_residual                0
# dtype: int64

# %%
dup_check(World_Happiness2_Report)
# Out:
# Duplicates found: False
#
# Number of duplicates: 0

# %%
data_frame_overview(World_Happiness3_Report)
# Out:
# Column names:
#  Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')
#
# Dimensions: (155, 12)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
# ...

# %%
World_Happiness3_Report.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
null_check(World_Happiness3_Report)
# Out:
# Total null values per row:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 150    0
# 151    0
# 152    0
# 153    0
# 154    0
# Length: 155, dtype: int64
#
# Total null values per column:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %%
dup_check(World_Happiness3_Report)
# Out:
# Duplicates found: False
#
# Number of duplicates: 0

# %%
data_frame_overview(World_Happiness4_Report)
# Out:
# Column names:
#  Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')
#
# Dimensions: (156, 9)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
# ...

# %%
World_Happiness4_Report.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
null_check(World_Happiness4_Report)
# Out:
# Total null values per row:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 151    0
# 152    0
# 153    0
# 154    0
# 155    0
# Length: 156, dtype: int64
#
# Total null values per column:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %%
dup_check(World_Happiness4_Report)
# Out:
# Duplicates found: False
#
# Number of duplicates: 0

# %%
data_frame_overview(World_Happiness5_Report)
# Out:
# Column names:
#  Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')
#
# Dimensions: (156, 9)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
# ...

# %%
World_Happiness5_Report.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
null_check(World_Happiness5_Report)
# Out:
# Total null values per row:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 151    0
# 152    0
# 153    0
# 154    0
# 155    0
# Length: 156, dtype: int64
#
# Total null values per column:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
dup_check(World_Happiness5_Report)
# Out:
# Duplicates found: False
#
# Number of duplicates: 0
